# %% [markdown]
# # Jupyterlab version

# %% [markdown]
# # Extract and process data into nodes and edges

# %%
import pickle
import json
import gzip
from pprint import pprint
import os.path

# %% [markdown]
# # Import data

# %% [markdown]
# Assumes that the data files are in a subfolder called 'Data'

# %%
# Written by Alex
# unzips the file and goes through it
# 1 line is 1 post

data_path = 'Data/'  #change dir to your project folder
filename = os.path.join(data_path, 'processed.1850k.jsonl.gz')

def iterate_posts():
    with gzip.open(filename, 'rb') as fd:
      for line in fd:
          yield json.loads(line)
            
gen = iterate_posts()
#next(gen)

# %%
# Collect a set of all usernames found in posts
# Using posts.pickle.gz allows 1 line = 1 name
# This file breaks replies off from the parent post
# so that we don't have to worry about parsing multiple
# names in one line.
# Once we haved a list of each username from each post,
# remove duplicates to get a full list of unique usernames
from collections import Counter

filename2 = os.path.join(data_path, 'posts.pickle.gz')

single_posts = pickle.load(gzip.open(filename2, 'rb'))
nodes = []
for post in single_posts.values():
    nodes.append(post['author'].replace(" ", "_")) # Need to remove spaces in a few names
    
user_post_count = Counter(nodes)

# %%
top_10k = user_post_count.most_common(10001)
top_10k = top_10k[1:10001]
len(top_10k)
# Out:
# 10000

# %%
nodes = [item[0] for item in top_10k]

# %%
top_10k
# Out:
# [('@ThomasFox', 537),
#  ('@IamfromQ', 448),
#  ('@CounterGlobalist', 408),
#  ('@TommyRobinson', 383),
#  ('@mitchellvii', 339),
#  ('@LibertyElaine', 310),
#  ('@WeLoveTrump', 305),
#  ('@handsomebuster', 303),
#  ('@MIZ37YandMaYh3m', 300),
#  ('@epochtimes', 297),
#  ('@Cherokeeowl', 256),
#  ('@Auldiedog', 248),
#  ('@1DRACARYS', 245),
#  ('@RebelAngel78', 241),
#  ('@americanshomer', 240),
#  ('@ihvurbk2', 234),
#  ('@Juanita7', 225),
#  ('@Murphycat2012', 224),
#  ('@BoroncarbideBonerMan', 221),
#  ('@ShadowOfDeath', 218),
#  ('@HelloFranklin', 217),
#  ('@Washingtonsangeloflight', 216),
#  ('@DCROKIT', 210),
#  ('@Viper8', 208),
#  ('@BuckeyeSIGI', 207),
#  ('@Hrothenb', 206),
#  ('@Tireshoptutoring', 200),
#  ('@Vasilievich', 198),
#  ('@GenZConservative1', 197),
#  ('@IMPatriotRU', 188),
#  ('@Terriehellman1', 187),
#  ('@cjtruth', 186),
#  ('@Lindas123', 186),
#  ('@ViolentVixen29', 185),
#  ('@Jennie33', 185),
#  ('@Cjames9702', 185),
#  ('@EllieBOfficial', 184),
#  ('@RedLiner', 177),
#  ('@Glorph', 175),
#  ('@LCandy', 175),
#  ('@candycarboni', 175),
#  ('@Sal72H', 174),
#  ('@Cobrarick98', 172),
#  ('@chucknellis', 169),
#  ('@Ediekiss', 169),
#  ('@UnsilentMajority2021', 166),
#  ('@JorjalexSTOPTHESTEAL', 166),
#  ('@Aliceitstime0817', 165),
#  ('@ConservativeLibrarian', 165),
#  ('@Dbongino', 163),
#  ('@gnewsorg', 161),
#  ('@BNelms', 161),
#  ('@NeverForget162021', 160),
#  ('@AmericanConservativesNews', 159),
#  ('@Onebadolepuddycat', 159),
#  ('@TRUMPSAMERICA2020', 158),
#  ('@mygiveafuckisbroken', 155),
#  ('@Coralkiss26', 155),
#  ('@Terryb158', 154),
#  ('@Hfcmedia64', 154),
#  ('@Crackerboy', 153),
#  ('@Fitz3215', 152),
#  ('@CraigTheTechTeacher', 151),
#  ('@noplacelikehome', 149),
#  ('@pineappleonapeach', 148),
#  ('@MB1164', 147),
#  ('@5smoothstones', 147),
#  ('@DaveDennison', 146),
#  ('@Debbiehalsey', 145),
#  ('@Maryn5683', 144),
#  ('@linwood', 143),
#  ('@Alesiaking2379', 143),
#  ('@Kaypsyche1', 143),
#  ('@QanonMemes', 141),
#  ('@Dnaz0427', 141),
#  ('@ntdnews', 140),
#  ('@Lawstaff26', 140),
#  ('@Serremmy', 139),
#  ('@Wellyworld', 139),
#  ('@Ztexanz', 139),
#  ('@JohnQGalt', 138),
#  ('@SummerNight1973', 138),
#  ('@JusticeByLight', 137),
#  ('@GatewayPundit', 137),
#  ('@Nateguez', 137),
#  ('@Theresa14837', 137),
#  ('@KimmyKesler', 137),
#  ('@GeneralSnob', 137),
#  ('@limengyan', 137),
#  ('@DineshDSouza', 136),
#  ('@TheRealJohnnyBravo', 136),
#  ('@kagbabe', 135),
#  ('@truthseekers2021', 134),
#  ('@MaskHysteria', 133),
#  ('@iAmFreedomMan', 133),
#  ('@Katew3651', 132),
#  ('@CKTwistedangel', 131),
#  ('@WarRoomPandemic', 130),
#  ('@Spaceforcecat', 128),
#  ('@gtakhotmail', 126),
#  ('@Captainanglin', 126),
#  ('@SeanHannity', 125),
#  ('@Marklevinshow', 125),
#  ('@Adaliabrand8', 125),
#  ('@Luckymee2', 124),
#  ('@Guyewing57', 124),
#  ('@Idealintuition', 124),
#  ('@Rob0303', 124),
#  ('@GratefulCuban', 123),
#  ('@F78pbass', 123),
#  ('@defendthelion', 122),
#  ('@PhanHuy888888', 121),
#  ('@TTexasRepublic', 121),
#  ('@Reginabutler1993', 121),
#  ('@RFoxfire', 120),
#  ('@Riddlson', 120),
#  ('@ldn4319', 118),
#  ('@Sheila75king', 118),
#  ('@Kurvetron', 117),
#  ('@ROKnROLLQZMDO', 117),
#  ('@Pedarz', 117),
#  ('@Talbotbrent5', 116),
#  ('@KitKat77777', 116),
#  ('@Sardarkhalsa52', 116),
#  ('@Roxlaw', 116),
#  ('@Johnrgmytruk', 116),
#  ('@MammaW4', 115),
#  ('@Neukanon', 114),
#  ('@Maewinston77', 113),
#  ('@Yojudenz', 113),
#  ('@WickedGood', 112),
#  ('@Chelsea102811', 112),
#  ('@Akwilliams924', 111),
#  ('@DigitalSwolljer', 110),
#  ('@TheMaineConservative', 110),
#  ('@MurderTheMedia', 109),
#  ('@Melissacody', 109),
#  ('@MichaelJPenney', 109),
#  ('@massecl7', 108),
#  ('@Bobbiplunkett', 108),
#  ('@SOMOTITBE', 108),
#  ('@zerohedge', 107),
#  ('@Ambersonjack85', 107),
#  ('@tjf2020', 106),
#  ('@Perfectpub', 106),
#  ('@Junevancleve', 105),
#  ('@TRUMPCHICK20', 105),
#  ('@Ivana1111', 105),
#  ('@Namztlam', 104),
#  ('@Fftjr899', 103),
#  ('@TheJamesLane', 103),
#  ('@WiseEnough', 103),
#  ('@HenHouse0204', 103),
#  ('@DONALDFUCKINGTRUMP', 103),
#  ('@Info972420564367', 103),
#  ('@GonvSurvival', 102),
#  ('@RobertEckert', 102),
#  ('@DominiqueFrankon', 102),
#  ('@Got2findit', 102),
#  ('@Allanwooden1', 102),
#  ('@CQCQ1', 102),
#  ('@Carmen4Truth', 101),
#  ('@Wwmurphy', 101),
#  ('@FetchingFeline', 101),
#  ('@DBL5555555', 101),
#  ('@Myfox2019', 101),
#  ('@ArdentPatriot', 100),
#  ('@Rosababy1111', 100),
#  ('@Mcgrocks888', 100),
#  ('@WhyeatyurWryld', 100),
#  ('@FlowerGirl47', 100),
#  ('@Joeybrooklyn1776', 100),
#  ('@Brenthurley1980', 100),
#  ('@BrendaEnuffAlready', 99),
#  ('@Pennyman', 99),
#  ('@Productor', 99),
#  ('@Musicandwhiskey', 99),
#  ('@Joemachesky', 98),
#  ('@Hgevaert', 98),
#  ('@Drewsandberg77', 98),
#  ('@richirich1963', 97),
#  ('@CitizenFreePress', 97),
#  ('@LaResistance', 97),
#  ('@Smileyfaithrjtz', 97),
#  ('@Ronhubbard1606', 97),
#  ('@Luvsbooks64', 97),
#  ('@Shadesofgrey83', 97),
#  ('@Tahoemtnbkr', 96),
#  ('@Crusaderpatriot', 95),
#  ('@Marthaesosa', 95),
#  ('@RealFakeNews', 95),
#  ('@Politicallyincorrectusa', 94),
#  ('@AvanteGardeKingdomRebel', 94),
#  ('@ProspectiveUSA1', 94),
#  ('@Shariwhittyphi', 94),
#  ('@Darkman3500', 94),
#  ('@Spurlock641291825665', 94),
#  ('@Maddpatriot', 94),
#  ('@Mishellespry', 93),
#  ('@RedTalonX', 93),
#  ('@Deadp00l', 93),
#  ('@Simino', 93),
#  ('@Debbieearpr1958', 93),
#  ('@realwayneroot', 92),
#  ('@DJtruthseeker', 92),
#  ('@LightsonUSA2020', 92),
#  ('@Chavezj33', 92),
#  ('@Footballchick030', 92),
#  ('@RossCappy', 92),
#  ('@Joyfillednomads', 91),
#  ('@Camosoul', 91),
#  ('@CleverCheetah', 91),
#  ('@kingofscot', 91),
#  ('@Yalak2019', 91),
#  ('@Romanbeauty', 91),
#  ('@TrumpNewsTeam', 90),
#  ('@Bill268147255225', 90),
#  ('@Geoffff', 90),
#  ('@QsoWoke', 90),
#  ('@Buddyboy53', 90),
#  ('@Stpatty72', 90),
#  ('@Patriot24007', 90),
#  ('@Bjscodywody', 89),
#  ('@PELOSIcomputergoodies', 89),
#  ('@IAMStudioProductionsLLC', 89),
#  ('@KnowThyself', 89),
#  ('@howiedubz', 89),
#  ('@Blackshoe', 89),
#  ('@RepublicKev', 89),
#  ('@KerrieInTheUK', 89),
#  ('@Youngalwaysforever1', 89),
#  ('@SamRiddle', 89),
#  ('@MarioATV', 89),
#  ('@HoTgoodolboy', 89),
#  ('@waynedupreeshow', 88),
#  ('@AncestorSignedDecOfIndependence1776', 88),
#  ('@GinoScarpa', 88),
#  ('@OTRTD', 88),
#  ('@Taborwoods1', 88),
#  ('@Ahceenarhodesgmailcom', 88),
#  ('@Deet2328', 88),
#  ('@VerdadesOfenden', 88),
#  ('@Carolbrown01', 88),
#  ('@Rosaaydee0817', 88),
#  ('@Gilisho6', 88),
#  ('@DrumsNmore', 87),
#  ('@Butterflygreen28', 87),
#  ('@72badodge52', 86),
#  ('@Hizboss33', 86),
#  ('@TheRealWakeUpMfers', 86),
#  ('@BamaRed1', 86),
#  ('@Tee007', 86),
#  ('@MAGADALLAS', 85),
#  ('@Shofarblower', 85),
#  ('@Dan151', 85),
#  ('@Dmills3710', 85),
#  ('@ElPercho', 85),
#  ('@Arch_angelz5', 85),
#  ('@Keyofthestar', 85),
#  ('@Flgal2', 85),
#  ('@maryanne', 85),
#  ('@ElJefeNevada', 84),
#  ('@rowdydowdy', 84),
#  ('@LaReinaHoney', 84),
#  ('@VanguardPatriot', 84),
#  ('@Lifechoices', 84),
#  ('@flintbedrock', 83),
#  ('@AddVibes', 83),
#  ('@Mainegirl1856033350555', 83),
#  ('@IceMan2', 83),
#  ('@AWarrior', 83),
#  ('@Justinbarber', 83),
#  ('@arhumes3', 83),
#  ('@InfoWars', 82),
#  ('@GIGina', 82),
#  ('@Gaultier', 82),
#  ('@Sinderac', 82),
#  ('@DMPatriot', 82),
#  ('@Rorydolin', 82),
#  ('@TrumpParty6365', 82),
#  ('@Stopthestealwiki', 82),
#  ('@LisaMaxwell', 82),
#  ('@AmericanPatriotsMAGA', 81),
#  ('@Milo', 81),
#  ('@10ztalk', 81),
#  ('@Bigshow', 81),
#  ('@BENFRANKLINBOT', 81),
#  ('@GaryADePietro', 81),
#  ('@Speterson39', 80),
#  ('@radavis', 80),
#  ('@LeahE01', 80),
#  ('@Proudboyscheerleader', 80),
#  ('@Kr4vMAGA', 80),
#  ('@Dennishuff56', 80),
#  ('@Dkhoppes', 80),
#  ('@motherissues', 80),
#  ('@Jd1719', 80),
#  ('@Jmjpa2020', 80),
#  ('@Cljensen67', 79),
#  ('@LiveLikeAPatriot', 79),
#  ('@Moodyblues6', 79),
#  ('@adawn5', 79),
#  ('@Duckduckswan', 79),
#  ('@Kfloresrn', 79),
#  ('@RedStatesRule', 79),
#  ('@Pelletier', 79),
#  ('@DiaperDonLost', 79),
#  ('@HelpTrumpHelpYou', 79),
#  ('@William5849', 78),
#  ('@TrumpNewsNow', 78),
#  ('@AtomicDawg', 78),
#  ('@Kpeklund91', 78),
#  ('@Moukee', 78),
#  ('@Pussykins', 78),
#  ('@Pixee99', 78),
#  ('@Gatorcoastie', 77),
#  ('@Amtatulli', 77),
#  ('@ThreePercenters', 77),
#  ('@JustCruz', 77),
#  ('@RealBreckWorsham', 77),
#  ('@2016MAGA2024', 77),
#  ('@Drwildasays', 77),
#  ('@RawRawTruth', 77),
#  ('@TennesseeGALinUtah', 77),
#  ('@Jakebe', 77),
#  ('@Striveupward', 77),
#  ('@12gourmetfoodie', 77),
#  ('@Ryanahlberg', 76),
#  ('@fightthefraud', 76),
#  ('@Leeshotfury', 76),
#  ('@Jenniferdeer', 76),
#  ('@Nfinity', 76),
#  ('@TheTommyCShow', 76),
#  ('@Samskemp262', 76),
#  ('@TrumpRockz2021', 76),
#  ('@TexiansRBest', 75),
#  ('@faithflagandfreedom', 75),
#  ('@brendasyl55', 75),
#  ('@Mach5', 75),
#  ('@Lorettashere', 75),
#  ('@THEACTIVATED', 75),
#  ('@Patitude', 75),
#  ('@Oomtown', 75),
#  ('@Patriotsteve', 75),
#  ('@Vermont1StMedia', 75),
#  ('@Vavadani1978', 75),
#  ('@Deanhohl', 75),
#  ('@NotARichGirl', 75),
#  ('@KBellePatriot', 75),
#  ('@Mchenrycop1055', 74),
#  ('@Esmeralda2020', 74),
#  ('@Mars64', 74),
#  ('@Gideon300amy', 74),
#  ('@Dave37048', 74),
#  ('@PeanutButterCup', 74),
#  ('@KipBigBoy', 74),
#  ('@GodTruthandIntegrityfirst', 74),
#  ('@IamPamela', 74),
#  ('@yeapy', 74),
#  ('@HakTxfire', 73),
#  ('@TAGM', 73),
#  ('@Marcg1957', 73),
#  ('@MABVET', 73),
#  ('@Mmfresno80', 73),
#  ('@Swmokie', 73),
#  ('@yaBetterGetRightWithGod', 73),
#  ('@Messagetothechurch', 73),
#  ('@PATRIOTofthe45th', 73),
#  ('@TrumpTelepathy', 73),
#  ('@fukchinafuktwitter', 73),
#  ('@Bansheeroughrider', 73),
#  ('@OANN', 72),
#  ('@Stephanhohil', 72),
#  ('@Sstricklett', 72),
#  ('@HollyRCL72', 72),
#  ('@Covidcattle', 72),
#  ('@MAGAJules1', 72),
#  ('@NunezLaboe', 72),
#  ('@WillisLyle', 72),
#  ('@Mcintoshconsulting20', 72),
#  ('@GEE', 71),
#  ('@SirBatman', 71),
#  ('@TiffanythePatriot', 71),
#  ('@StormsComingSQQn', 71),
#  ('@America2point0', 71),
#  ('@DarKell', 71),
#  ('@ConservatismIsSociopathy', 71),
#  ('@Ecotopiatexas', 70),
#  ('@theblaze', 70),
#  ('@Mike1959', 70),
#  ('@Gungadon', 70),
#  ('@Peterandlindamacdonnell', 70),
#  ('@CommunistsDeserveToDie', 70),
#  ('@Freedom4TheWin', 70),
#  ('@Sandees', 70),
#  ('@Loril3069', 70),
#  ('@courchesnes', 70),
#  ('@Trumpwhitehouse', 70),
#  ('@Ollie12119', 70),
#  ('@Texan4Truth', 70),
#  ('@Maremakoid', 70),
#  ('@GodAnon', 70),
#  ('@Remarkable001', 70),
#  ('@PainterRandy', 70),
#  ('@BeachMilk', 69),
#  ('@Mmorton1596', 69),
#  ('@DIPYO', 69),
#  ('@AdeniranDeji', 69),
#  ('@DApling', 69),
#  ('@BlackLabelAndCoke', 69),
#  ('@blakeRenMan', 69),
#  ('@Marlaclark5837', 69),
#  ('@Prezzy91', 69),
#  ('@AlexJonesWins', 69),
#  ('@Landoflakes', 69),
#  ('@naturalnews', 69),
#  ('@Steveondreako', 69),
#  ('@lmg', 69),
#  ('@Johnurey52', 69),
#  ('@dfwactivist', 68),
#  ('@Candace808', 68),
#  ('@NickelNews', 68),
#  ('@Irishjam7', 68),
#  ('@Samspde', 68),
#  ('@RealLAThomas', 68),
#  ('@QVetsowned', 68),
#  ('@Seekthetruth05', 68),
#  ('@IrisCrane15', 68),
#  ('@Claralou2', 68),
#  ('@TomPayne1774', 68),
#  ('@Sstreck4201', 68),
#  ('@SavingAmerica', 68),
#  ('@YevaG007', 68),
#  ('@SaraTruthSeeker', 68),
#  ('@Markrybeck1956', 68),
#  ('@PRESIDENTTRUMPTWEETS', 67),
#  ('@luvbec', 67),
#  ('@Caligalsac', 67),
#  ('@GreatfulAmericanFormerlySnakebitCajunTwitterSucks', 67),
#  ('@tonysworld', 67),
#  ('@JLaw1986', 67),
#  ('@MountainShark', 67),
#  ('@VanArsdale', 67),
#  ('@HWH805', 67),
#  ('@wdpddb2019', 67),
#  ('@Judesmc', 67),
#  ('@Marie1773056', 67),
#  ('@PaleoLutheranObserver', 67),
#  ('@Montanakat2', 67),
#  ('@Dorrie', 67),
#  ('@Lucas0538', 67),
#  ('@Tluva777', 67),
#  ('@AmandaDavis1', 67),
#  ('@Azzurro13', 67),
#  ('@Freetoplay1617', 67),
#  ('@Altimahealthcare11', 67),
#  ('@Ourlady3406638415216', 67),
#  ('@AKluvsTRUMP', 66),
#  ('@MisterBBB', 66),
#  ('@LitCountryGirl', 66),
#  ('@Clownworldbrigade', 66),
#  ('@Katzmania9', 66),
#  ('@michaelreilly', 66),
#  ('@Titanium', 66),
#  ('@McDaniel1966', 66),
#  ('@TaoLife', 66),
#  ('@4651lainey', 66),
#  ('@SophieRo', 66),
#  ('@DemsRiggedElection2020', 66),
#  ('@Sfkatz13', 66),
#  ('@Nickmattkat', 66),
#  ('@JamesLukac', 66),
#  ('@Airypointrfd', 66),
#  ('@Bobbyferrari', 66),
#  ('@Gordonbankier', 66),
#  ('@DrakeLonghorn', 66),
#  ('@TheVoiceofReason7', 66),
#  ('@Laurlauri', 66),
#  ('@Missastrong', 66),
#  ('@sfslotterbeck', 66),
#  ('@Nanawellie', 65),
#  ('@RogFishes', 65),
#  ('@Cdcimagines', 65),
#  ('@KennethRollins', 65),
#  ('@AppleJax', 65),
#  ('@KAGRevolution', 65),
#  ('@PrezElectDonkey', 65),
#  ('@Joebronsky', 65),
#  ('@Sweetliljessicalynn', 65),
#  ('@rawdawgbuffalo', 65),
#  ('@heysharan', 65),
#  ('@Tigerstripes', 65),
#  ('@Supra9112003', 65),
#  ('@Abonesz39', 65),
#  ('@patbick55', 65),
#  ('@evilWONTwin1', 65),
#  ('@MAMASLAVV', 65),
#  ('@JustMyNameHere', 65),
#  ('@SteveBash', 65),
#  ('@Diannekirk', 65),
#  ('@Pebblecreek11', 65),
#  ('@ConservatiiveForTrump', 64),
#  ('@DeplorableEarl', 64),
#  ('@SeniorChaplain', 64),
#  ('@GrandmaPattiA', 64),
#  ('@TexasTarheel', 64),
#  ('@Golfball984', 64),
#  ('@RAnon78', 64),
#  ('@Ksdlugopolski81', 64),
#  ('@Scrappyindependent', 64),
#  ('@ConservativeStudio', 64),
#  ('@KevinChaulk', 64),
#  ('@raybaez', 64),
#  ('@Alpha1957', 64),
#  ('@Deborahlg', 64),
#  ('@Truthtalker205', 64),
#  ('@BornThisWay', 64),
#  ('@potamusman', 64),
#  ('@Gatormanradio', 64),
#  ('@MAGAnFREEDOM', 64),
#  ('@GaDawg1', 63),
#  ('@Jsolomonreports', 63),
#  ('@Thompsonannette100', 63),
#  ('@junkfruit77', 63),
#  ('@Ronbrightwell58', 63),
#  ('@Frederickgrc826150475472', 63),
#  ('@Cowboyhorsemaster', 63),
#  ('@thewordofyahweh', 63),
#  ('@Bobsentme', 63),
#  ('@Tomroberts2289420948', 63),
#  ('@Durangoclaudia425', 63),
#  ('@LucidKeK', 63),
#  ('@Jllaxton', 63),
#  ('@StealthX21', 63),
#  ('@MeyersMike', 62),
#  ('@FactSeekers', 62),
#  ('@ManuelSuarezAvila', 62),
#  ('@DarkForestSpirit', 62),
#  ('@JoeBidenIsNotMyPresidentDotNews', 62),
#  ('@Standyourground', 62),
#  ('@Driveangry327', 62),
#  ('@Rdsizemore1945', 62),
#  ('@Springless', 62),
#  ('@Theeditorialguru', 62),
#  ('@Cromag31', 62),
#  ('@RealAmericanSun', 62),
#  ('@LastStand2019', 62),
#  ('@Jeep2007Mb', 62),
#  ('@Tonto61', 62),
#  ('@Ericrobinsonmm', 62),
#  ('@NOSAFESPACEFORMAGAS', 62),
#  ('@ProudTrumperForever', 62),
#  ('@Mayo97', 62),
#  ('@Suzette007', 62),
#  ('@Rabidcow', 62),
#  ('@funkdapopo', 62),
#  ('@moonstone71', 62),
#  ('@holyDoll', 62),
#  ('@vness', 62),
#  ('@nwfpolitical', 61),
#  ('@Jezza616175893134', 61),
#  ('@Shakedawgg', 61),
#  ('@ThePatriotHammer', 61),
#  ('@SalMal65', 61),
#  ('@TeddiZaps', 61),
#  ('@Angelboydj', 61),
#  ('@dickwood', 61),
#  ('@Gaillee2bme2', 61),
#  ('@Sgventi', 61),
#  ('@RayJPolitics', 61),
#  ('@DavidIrvine1', 61),
#  ('@Dave1238', 61),
#  ('@Theconservativechica', 61),
#  ('@Hcrichfield', 61),
#  ('@Bryanfroggymark', 61),
#  ('@JunebugOh', 61),
#  ('@Rosadominy', 61),
#  ('@cegiggmail', 61),
#  ('@Wfrost57', 61),
#  ('@Lamp77', 61),
#  ('@Butterflies2u65', 61),
#  ('@adirondackersforamerica', 61),
#  ('@Tracilee', 60),
#  ('@LibertyLover0912', 60),
#  ('@blaster11763', 60),
#  ('@AmyLou', 60),
#  ('@Blossom133', 60),
#  ('@Lpsmith197482', 60),
#  ('@Domchanec', 60),
#  ('@DaveHoggwashwasgettinghisbicycleandcamera', 60),
#  ('@ZAnonymous', 60),
#  ('@saffari', 60),
#  ('@CunnningLinguist', 60),
#  ('@NewsFlash', 60),
#  ('@LarryDCook', 60),
#  ('@Lourob12', 60),
#  ('@N911JD', 60),
#  ('@Doodledog3', 60),
#  ('@Girlsontherun321', 60),
#  ('@Jillyanwalker', 60),
#  ('@Hayloft44', 60),
#  ('@WitchDoctor6', 59),
#  ('@JCFitzEdward', 59),
#  ('@Realnews4U', 59),
#  ('@Lewisclelon', 59),
#  ('@SRons123', 59),
#  ('@Whatfingereditor', 59),
#  ('@Mbissanti', 59),
#  ('@Margaretfreja', 59),
#  ('@DTrumpStillMyPresident', 59),
#  ('@Runningwolf111', 59),
#  ('@LibertyInfo', 59),
#  ('@GeorgeWu', 59),
#  ('@greenmask', 59),
#  ('@Mariapeterson277', 59),
#  ('@DeplorableChris', 59),
#  ('@JoeFreedomLover', 59),
#  ('@Bugsfbunny', 59),
#  ('@Misticworks', 59),
#  ('@Lingchow1', 59),
#  ('@TheRealBeef', 59),
#  ('@TheOfficeofThomasPaine', 59),
#  ('@Jacm051', 59),
#  ('@StormIsUponUs', 58),
#  ('@Rwchand1968', 58),
#  ('@lakemonstercl', 58),
#  ('@Heybroons', 58),
#  ('@LifeNews', 58),
#  ('@Axilleus', 58),
#  ('@Trumpper', 58),
#  ('@RoniCox', 58),
#  ('@ladymaga88', 58),
#  ('@HanginHillary', 58),
#  ('@Pascaldibello', 58),
#  ('@Muligan4me', 58),
#  ('@Marilynbar', 58),
#  ('@araxe', 58),
#  ('@Bryanmueller32', 58),
#  ('@Climmyr50', 58),
#  ('@Rockalu', 58),
#  ('@Comradekewl', 58),
#  ('@Descartes', 58),
#  ('@Rstmmr', 58),
#  ('@Kbrannon', 58),
#  ('@DolandDrumpf', 58),
#  ('@HeidiRN', 58),
#  ('@RealDonaldTrumpsupporter', 58),
#  ('@RockyOleary', 58),
#  ('@Mgdelucia13', 58),
#  ('@Akasha5t', 58),
#  ('@LIGHT2020', 58),
#  ('@Knighttalx', 58),
#  ('@jakeroedel', 57),
#  ('@Jayman2124', 57),
#  ('@RepublicofTexas31', 57),
#  ('@JoeySalads', 57),
#  ('@Hublette', 57),
#  ('@Jaxon026', 57),
#  ('@JRaliegh53', 57),
#  ('@Redbud', 57),
#  ('@PresidentElectBoilingPointNews', 57),
#  ('@MattBell1', 57),
#  ('@cbogowitz', 57),
#  ('@JustOneTulip', 57),
#  ('@Hawaii2020', 57),
#  ('@AdamPsutka', 57),
#  ('@LilR', 57),
#  ('@Redheadedlover15', 57),
#  ('@Vic2855', 57),
#  ('@LindyWithAWhy', 57),
#  ('@TruthNeverChanges', 57),
#  ('@Tesspilati', 57),
#  ('@Azvallee', 57),
#  ('@FaithfulPatriot71', 57),
#  ('@Thiessen130', 57),
#  ('@SapphicGoddess', 57),
#  ('@PatriotsWakeUp', 57),
#  ('@Td89419', 57),
#  ('@weasespieces', 57),
#  ('@Aintchaprecious', 57),
#  ('@Murade63', 57),
#  ('@Laylagonini26677', 56),
#  ('@BushelandaPeck', 56),
#  ('@SupportLinWood', 56),
#  ('@Zeppefan', 56),
#  ('@BikersForDonaldTrump', 56),
#  ('@Ruthukariuki2', 56),
#  ('@ChrisPBaqon', 56),
#  ('@LoyalPatriot', 56),
#  ('@EWillHelpYou', 56),
#  ('@Awakened144', 56),
#  ('@Scottdavislasvegas', 56),
#  ('@HappyLife1968', 56),
#  ('@JudefromFlorida', 56),
#  ('@Zwin', 56),
#  ('@Adams684', 56),
#  ('@FightforFreedom53', 56),
#  ('@LATINA4TRUMP2020', 56),
#  ('@Seanchaidh', 56),
#  ('@ProudBoysGirlsAK', 56),
#  ('@FansOfTrump', 56),
#  ('@TxBBQGuys', 56),
#  ('@ECHOPLZ', 56),
#  ('@FarmerB3', 56),
#  ('@josephine6591', 56),
#  ('@Dragonflie63', 56),
#  ('@WeWin', 56),
#  ('@prospernot', 56),
#  ('@Crolson60', 56),
#  ('@Baseba8188', 56),
#  ('@theyellowbrickroad', 56),
#  ('@XRAY2', 56),
#  ('@JasperJax', 56),
#  ('@Bettygutierrez51', 56),
#  ('@DaveH2019', 56),
#  ('@M0riarty1', 56),
#  ('@Partiesplusteri', 55),
#  ('@pinklady50', 55),
#  ('@CnsrvativeHusky', 55),
#  ('@TheQuestion', 55),
#  ('@Noblebeard', 55),
#  ('@Howardmclain', 55),
#  ('@davfl777', 55),
#  ('@Twlghtangel', 55),
#  ('@Gabbymiller21', 55),
#  ('@Jercarolm', 55),
#  ('@littlemamapatriot', 55),
#  ('@alwaysatrumpgirl', 55),
#  ('@InSeattle', 55),
#  ('@SaltyEels', 55),
#  ('@Rjbes59', 55),
#  ('@RideshareGuyPGH', 55),
#  ('@Texvetzm77', 55),
#  ('@itsaboutchoice', 55),
#  ('@Kbell1486', 55),
#  ('@freenaynow', 55),
#  ('@JelloShells', 55),
#  ('@JenniferTheisHafer', 55),
#  ('@QueenMarita', 55),
#  ('@mrm59', 55),
#  ('@Moniie', 55),
#  ('@Thejacksonblack', 55),
#  ('@SouthernBelle59', 55),
#  ('@LesleyPeirce', 55),
#  ('@incomingfrom1776', 55),
#  ('@TrumpTreason45', 55),
#  ('@Natalia13', 55),
#  ('@Conservativarmy', 54),
#  ('@Nanster', 54),
#  ('@1776stonewall', 54),
#  ('@HandicapRay', 54),
#  ('@Newportspot', 54),
#  ('@WarriorofGod', 54),
#  ('@AussieVoices', 54),
#  ('@Simoblade58', 54),
#  ('@shawnMary', 54),
#  ('@SlmMoorhouse', 54),
#  ('@PamLarson', 54),
#  ('@haicim', 54),
#  ('@Imchuckyhello', 54),
#  ('@JaCoreyLewis', 54),
#  ('@DrAnaMihalcea', 54),
#  ('@StopandThinkNews', 54),
#  ('@JamesCollins018018850506', 54),
#  ('@Catmandu50', 54),
#  ('@BreathFartNews', 54),
#  ('@KAGUSA2020', 54),
#  ('@ToniD3', 54),
#  ('@AOL', 54),
#  ('@Zoomzoom2', 54),
#  ('@DrMikey', 54),
#  ('@Chudipaul2017', 54),
#  ('@maryannC258', 54),
#  ('@HimalayaWashingtonDC', 54),
#  ('@Mindflood', 54),
#  ('@TeamTrump', 53),
#  ('@Goovie2', 53),
#  ('@SkypilotTurboC195', 53),
#  ('@KnightsTemplar7', 53),
#  ('@ArnoId', 53),
#  ('@DonaldTrumpfor2020', 53),
#  ('@45greatestofalltime', 53),
#  ('@Goodwinaaron0419', 53),
#  ('@Irishlove', 53),
#  ('@Fiskayers', 53),
#  ('@HerbertReed', 53),
#  ('@KarenWatson', 53),
#  ('@guardianquill69', 53),
#  ('@Lilapeterson7', 53),
#  ('@MAGARidgerunner', 53),
#  ('@PepperLove', 53),
#  ('@Susansmith113', 53),
#  ('@AlyzahKat', 53),
#  ('@JulsB', 53),
#  ('@Zarzben', 53),
#  ('@Mitesor21', 53),
#  ('@Alicedixon40', 53),
#  ('@Ssglaciergirl25', 53),
#  ('@JBiNMP2020', 53),
#  ('@Fordeat1984AFM', 53),
#  ('@Susanfor45', 53),
#  ('@Kggatx', 53),
#  ('@Patriot1126', 53),
#  ('@HANGCLINTONCABAL', 53),
#  ('@Bobmodig', 53),
#  ('@FirefighterBoston617', 53),
#  ('@ParlerUser217', 53),
#  ('@LibertyByLocke', 53),
#  ('@DrJhouse5483', 53),
#  ('@Hqizme', 53),
#  ('@Dave02359', 52),
#  ('@Saltlife22', 52),
#  ('@Geraldmirabal', 52),
#  ('@Blondiesilver', 52),
#  ('@Alibruni', 52),
#  ('@W00dchuk', 52),
#  ('@Asm610', 52),
#  ('@Anticommie', 52),
#  ('@dryan7', 52),
#  ('@Myyellowf100', 52),
#  ('@Squirrelly', 52),
#  ('@Tographer', 52),
#  ('@damiandog', 52),
#  ('@peko007', 52),
#  ('@CinderellaMan2', 52),
#  ('@PoisonIvy', 52),
#  ('@Mg5167', 52),
#  ('@Nattiegirl', 52),
#  ('@PBCowboy', 52),
#  ('@Marinakl', 52),
#  ('@DylanWheeler511', 52),
#  ('@Muench520', 52),
#  ('@Sparky145', 52),
#  ('@DonGrizzly', 52),
#  ('@Visualstudiodatatools', 52),
#  ('@QElle', 52),
#  ('@Gswomac', 52),
#  ('@Jfarris122', 52),
#  ('@Lbruce401', 52),
#  ('@DeportDemocrats', 52),
#  ('@Hunt4TheTRUTH', 52),
#  ('@Jdsavant', 52),
#  ('@Susailee', 52),
#  ('@Coalstream', 52),
#  ('@MAKAIOmessenger', 52),
#  ('@Blynn07', 51),
#  ('@Jodi56', 51),
#  ('@Dac1911', 51),
#  ('@Reeseysnotsorry', 51),
#  ('@Colansson', 51),
#  ('@LauraLoomer', 51),
#  ('@JustTheNews', 51),
#  ('@Cynthiaschonefeld', 51),
#  ('@NaoACensuraDaNom', 51),
#  ('@Evaluation', 51),
#  ('@MakingLemonade', 51),
#  ('@Gunnary64', 51),
#  ('@Mthardwear5', 51),
#  ('@WeAreTheNews', 51),
#  ('@Elcymaia300', 51),
#  ('@TheAngelPreneur', 51),
#  ('@Monique62Hughes', 51),
#  ('@LoriM7732', 51),
#  ('@Dlw20161950', 51),
#  ('@ParlerMiser', 51),
#  ('@Wejoly', 51),
#  ('@davep', 51),
#  ('@Milesy45', 51),
#  ('@HermanCovid', 51),
#  ('@Southerncommand', 51),
#  ('@Lovesdisney2875', 51),
#  ('@ProTrump1966', 51),
#  ('@TheGateSpy', 51),
#  ('@SquirrelgirlJn', 51),
#  ('@Kelete25', 51),
#  ('@TruthReport', 51),
#  ('@Justnews2', 51),
#  ('@MELQARTNAZARIGHT', 51),
#  ('@brokenyokez', 51),
#  ('@JasonOnBlast', 50),
#  ('@WittyAmericanPatriot', 50),
#  ('@StopTheSteal', 50),
#  ('@Cassandra', 50),
#  ('@Angvan19', 50),
#  ('@thewashingtonpundit', 50),
#  ('@LLKmakenup', 50),
#  ('@jjjflawless', 50),
#  ('@Medpass37', 50),
#  ('@JoeyCamp2020', 50),
#  ('@ChanaHennessey', 50),
#  ('@HiveCaptain', 50),
#  ('@GameOver', 50),
#  ('@HatleyChris', 50),
#  ('@Thepeoplespeople', 50),
#  ('@Chienhut68', 50),
#  ('@JoJoWAstate', 50),
#  ('@CureChan', 50),
#  ('@Godwithus', 50),
#  ('@Suil', 50),
#  ('@2highTwophly', 50),
#  ('@Seaweed16', 50),
#  ('@Davidjones720', 50),
#  ('@karenlane52', 50),
#  ('@mtursi2000', 50),
#  ('@Tommy8175', 50),
#  ('@ThePrisonerNumberSix', 50),
#  ('@LionsnotLambs', 50),
#  ('@AQPATRON', 50),
#  ('@Eurotrash14', 50),
#  ('@WETP', 50),
#  ('@EdwardCalame', 50),
#  ('@Boatsailor594', 50),
#  ('@DontCoitusMyCOTUS', 50),
#  ('@roarofthelion', 50),
#  ('@Littlebeagles', 50),
#  ('@1976Patri0t', 50),
#  ('@jenniev101', 50),
#  ('@Lakeman1014', 50),
#  ('@Warmat52000', 50),
#  ('@Chanceman', 50),
#  ('@JordanSather', 49),
#  ('@TheBulldogg', 49),
#  ('@Mikeproverbs9v10', 49),
#  ('@QAQNON', 49),
#  ('@ShadowWolf44', 49),
#  ('@KiLLaKeLLs', 49),
#  ('@Ebalman1979', 49),
#  ('@TonyAce', 49),
#  ('@Faithycakes', 49),
#  ('@QTAnon1', 49),
#  ('@LuxLexAurum', 49),
#  ('@LightYearsAway', 49),
#  ('@RedPillJill', 49),
#  ('@Tchand1958', 49),
#  ('@changetheworld2', 49),
#  ('@Twest1953', 49),
#  ('@Logan5kory7', 49),
#  ('@LionsNotSheeeep', 49),
#  ('@Pax2Sofie', 49),
#  ('@elizabethbotros', 49),
#  ('@sidders', 49),
#  ('@bicentennialkris10', 49),
#  ('@20XxFREEDOMxX20', 49),
#  ('@Qanonhispano', 49),
#  ('@Xsf18cdf', 49),
#  ('@Christyis33', 49),
#  ('@Adubay03', 49),
#  ('@Bostonstrongtrump', 49),
#  ('@DrainTheOcean45', 49),
#  ('@quittwit', 49),
#  ('@BethocAeilflaed', 49),
#  ('@FaithCountryFamily', 49),
#  ('@Cm8707', 49),
#  ('@KeithF54', 49),
#  ('@Crushrush007', 49),
#  ('@Bop1', 49),
#  ('@Wynston', 49),
#  ('@TexasMiddleEastVetStandingBy', 49),
#  ('@Shack', 49),
#  ('@Sandeehull', 49),
#  ('@Lommelp', 49),
#  ('@LDLW90', 49),
#  ('@thomasj17431826', 49),
#  ('@Daisze', 49),
#  ('@TeeneBean', 49),
#  ('@Downtheroadmovers', 49),
#  ('@ErinBevins', 49),
#  ('@Terricat5', 49),
#  ('@redpillwarrior', 49),
#  ('@Pm512', 49),
#  ('@X3haganx3', 49),
#  ('@andrebu', 49),
#  ('@WeloveDonaldTrumpusa', 48),
#  ('@Linkinbio', 48),
#  ('@Trish1958', 48),
#  ('@Edgold67', 48),
#  ('@Housecat598', 48),
#  ('@joycegeyer123jp', 48),
#  ('@WakeUpAmericatheOriginal', 48),
#  ('@Mephebosheth', 48),
#  ('@ConservativeMediaNews', 48),
#  ('@Salliari', 48),
#  ('@Jerry73', 48),
#  ('@Johnnybriggsjcb', 48),
#  ('@Scarol', 48),
#  ('@Patlee9', 48),
#  ('@Sharkymailbox', 48),
#  ('@wallace09', 48),
#  ('@heatherdevito', 48),
#  ('@Newman5015', 48),
#  ('@Babybreathoo3', 48),
#  ('@EvanMedia', 48),
#  ('@Letsroll127', 48),
#  ('@Michelle37', 48),
#  ('@rossr2878', 48),
#  ('@HawkFeather', 48),
#  ('@Lipford', 48),
#  ('@GaryJPalys', 48),
#  ('@Rtchavez', 48),
#  ('@Terwvrn', 48),
#  ...]

# %%
# Out:
#   File "<ipython-input-38-b763f69c4f4d>", line 1
#     user_post_count[''@gatewaypundit']
#                                       ^
# SyntaxError: EOL while scanning string literal

# %%
nodes[:100]
# Out:
# ['@ThomasFox',
#  '@IamfromQ',
#  '@CounterGlobalist',
#  '@TommyRobinson',
#  '@mitchellvii',
#  '@LibertyElaine',
#  '@WeLoveTrump',
#  '@handsomebuster',
#  '@MIZ37YandMaYh3m',
#  '@epochtimes',
#  '@Cherokeeowl',
#  '@Auldiedog',
#  '@1DRACARYS',
#  '@RebelAngel78',
#  '@americanshomer',
#  '@ihvurbk2',
#  '@Juanita7',
#  '@Murphycat2012',
#  '@BoroncarbideBonerMan',
#  '@ShadowOfDeath',
#  '@HelloFranklin',
#  '@Washingtonsangeloflight',
#  '@DCROKIT',
#  '@Viper8',
#  '@BuckeyeSIGI',
#  '@Hrothenb',
#  '@Tireshoptutoring',
#  '@Vasilievich',
#  '@GenZConservative1',
#  '@IMPatriotRU',
#  '@Terriehellman1',
#  '@cjtruth',
#  '@Lindas123',
#  '@ViolentVixen29',
#  '@Jennie33',
#  '@Cjames9702',
#  '@EllieBOfficial',
#  '@RedLiner',
#  '@Glorph',
#  '@LCandy',
#  '@candycarboni',
#  '@Sal72H',
#  '@Cobrarick98',
#  '@chucknellis',
#  '@Ediekiss',
#  '@UnsilentMajority2021',
#  '@JorjalexSTOPTHESTEAL',
#  '@Aliceitstime0817',
#  '@ConservativeLibrarian',
#  '@Dbongino',
#  '@gnewsorg',
#  '@BNelms',
#  '@NeverForget162021',
#  '@AmericanConservativesNews',
#  '@Onebadolepuddycat',
#  '@TRUMPSAMERICA2020',
#  '@mygiveafuckisbroken',
#  '@Coralkiss26',
#  '@Terryb158',
#  '@Hfcmedia64',
#  '@Crackerboy',
#  '@Fitz3215',
#  '@CraigTheTechTeacher',
#  '@noplacelikehome',
#  '@pineappleonapeach',
#  '@MB1164',
#  '@5smoothstones',
#  '@DaveDennison',
#  '@Debbiehalsey',
#  '@Maryn5683',
#  '@linwood',
#  '@Alesiaking2379',
#  '@Kaypsyche1',
#  '@QanonMemes',
#  '@Dnaz0427',
#  '@ntdnews',
#  '@Lawstaff26',
#  '@Serremmy',
#  '@Wellyworld',
#  '@Ztexanz',
#  '@JohnQGalt',
#  '@SummerNight1973',
#  '@JusticeByLight',
#  '@GatewayPundit',
#  '@Nateguez',
#  '@Theresa14837',
#  '@KimmyKesler',
#  '@GeneralSnob',
#  '@limengyan',
#  '@DineshDSouza',
#  '@TheRealJohnnyBravo',
#  '@kagbabe',
#  '@truthseekers2021',
#  '@MaskHysteria',
#  '@iAmFreedomMan',
#  '@Katew3651',
#  '@CKTwistedangel',
#  '@WarRoomPandemic',
#  '@Spaceforcecat',
#  '@gtakhotmail']

# %%
def get_list_of_users(post):
    """ 
    Extract all usernames from each post

    Note:
        There can be None, one, or more usernames in a post.
     
     Args:
         post (dict): Yielded by iterate_posts()

    Attributes:
        users (dict): Used to collect usernames 
        
    Returns:
        users: Tuple of usernames from each post. Can contain any number of usernames.
    """    

    users = []
    try:
        for post_item in post['posts']:                
            users.append(post_item['author_username'].replace(" ", "_"))
    except KeyError:
        if len(users)>1:
            return tuple(users) #list of usernames from ONE(1) post
        else:
            return None

# %%
# Collect a list of tuples of of length 2 or more usernames from posts
# Filters out lists of None and lists with only 1 user. This is why 'minimum_posts' of 2 is unneeded.
# The exception is triggered by reaching the end of the JSONL file.
def get_edges():
    user_tuple_list=[]
    edges_temp=[]

    try:
        while True:
            user_tuple_list.append(get_list_of_users(next(gen))) 
    except:  
        user_tuple_list = list(set(user_tuple_list))
        for user_list in user_tuple_list:
#            if user_list != None and len(user_list)>1:
            if user_list != None:
                edges_temp.append(user_list)
            else:
                continue
        print("Complete")
        return edges_temp

# %%
def split_edges(all_edges):
    """  
    Split tuples into tuples of length 2 and remove duplicates.

    Args:
        all_edges (list of tuples): These tuples vary in length.

    Attributes: 
        user_list (list): Keeps tuples generated/passed by for loop.
        
    Returns:
        user_list (list of tuples): Each tuple is of length 2 and duplicates are removed.
        
    """

    user_list = []
    
    for user_tuple in all_edges:
        if len(user_tuple)==2:
            user_list.append(user_tuple)
        else:
            for username in user_tuple:
                if username!=user_tuple[0]:
                    user_list.append((user_tuple[0],username))
                else:
                    continue
            continue
    return list(set(user_list))

# %%
def remove_low_posters(edges):
    temp_list = []
    for username_tuple in edges:
        name_list = []
        for username in username_tuple:
            if username in nodes:
                name_list.append(username)
            else:
                pass
        if len(name_list)>1:
            temp_list.append(tuple(name_list))
        else:
            pass
    return temp_list

# %%
all_edges = get_edges()
print(f'all_edges is a {type(all_edges)} of {type(all_edges[0])} containing {type(all_edges[0][0])}')
len(all_edges)
# Out:
# Complete
# all_edges is a <class 'list'> of <class 'tuple'> containing <class 'str'>
# 141016

# %%
# Make all elements of edges to be tuples of length 2 with duplicates removed.
edges = split_edges(all_edges)
len(edges)
# Out:
# 229235

# %%
high_posters = remove_low_posters(edges)
len(high_posters)

# %%
len(high_posters)
# Out:
# 61738

# %%
high_posters[:10]
# Out:
# [('@IamfromQ', '@StayAmerica'),
#  ('@MrMayor', '@Rtchavez'),
#  ('@BenMyers1262', '@Dalesloc'),
#  ('@realwayneroot', '@Jhanco1'),
#  ('@CitizenFreePress', '@Mdpope1'),
#  ('@realwayneroot', '@FistfulofTrumpism'),
#  ('@KPatriot21', '@RepEricSwalwell'),
#  ('@Shariwhittyphi', '@adirondackersforamerica'),
#  ('@TheNewAmericanConservative', '@Heathermillertime'),
#  ('@Linkinbio', '@Pjcali')]

# %%
# save the nodes and edges to a file
# TODO: Write code to read in the files to the appropriate variables so that we don't have to run all of the above code again
graph_path = 'Graph/'

open(os.path.join(graph_path,'edges.txt'), 'w').write('\n'.join('%s %s' % x for x in high_posters))
#open(os.path.join(graph_path,'edges with low posters removed.txt'), 'w').write('\n'.join('%s %s' % x for x in high_posters))
open(os.path.join(graph_path,'nodes.txt'), 'w').write('\n'.join('%s' % x for x in nodes))
# Out:
# 132794
